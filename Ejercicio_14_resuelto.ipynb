# %% [markdown]
# <a href="https://colab.research.google.com/github/Alahin04/Ejercicio-N14-POO-Resuelto/blob/main/Ejercicio_14_resuelto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejercicio 14 - Samuel López
import math

class Calculos:
  @staticmethod
  def calcular_cuadr(numero):
    return math.pow(numero, 2)

  @staticmethod
  def calcular_cubo(numero):
    return math.pow(numero, 3)

numero = 4.0
cuadrado = Calculos.calcular_cuadr(numero)
cubo = Calculos.calcular_cubo(numero)

print("Cuadrado:" , cuadrado)
print("Cubo:" , cubo)
# Out:
# Cuadrado: 16.0
# Cubo: 64.0
